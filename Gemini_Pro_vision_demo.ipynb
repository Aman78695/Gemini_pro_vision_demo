# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman78695/Gemini_pro_vision_demo/blob/main/Gemini_Pro_vision_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 6.1 MB/s eta 0:00:00

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display,Markdown

# %%
import os
GOOGLE_API_KEY='AIzaSyDxBWVMDba4f46vsatrvBGJP__bdHvqbMw'
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model=genai.GenerativeModel('gemini-pro')

# %%
response=model.generate_content('what is gpt4')

# %%
response.text

# %%
import PIL.Image

# %%
img=PIL.Image.open('/content/WhatsApp Image 2022-11-03 at 18.19.52 (1).jpeg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1544x1544>

# %%
vision_model=genai.GenerativeModel('gemini-pro-vision')

# %%
response=vision_model.generate_content(img)

# %%
response.text
# Out:
# ' 25. If two straight lines intersect each other, then vertically opposite angles are equal.\na. Both Assertion (A) and Reason (R) are true and Reason (R) is the correct explanation of Assertion (A).\nb. Both Assertion (A) and Reason (R) are true and Reason (R) is not the correct explanation of Assertion (A).\nc. Assertion (A) is true but Reason (R) is false.\nd. Assertion (A) is false but Reason (R) is true.\n\n27. In the given figure, the angles a and b are in the ratio 2:3. Find angle c.\n\n28. Ram and Ravi have the same weight. If both of them gain weight by 2 kg, how will their new weights be compared?\n\n29. If x + x^4 = 4, then find the value of x^2 + 1/x\n\n30. In the given figure XOY is a straight line and a - b = 78o, find the value of a and b.\n\nOR\n\nIf one angle of a triangle is equal to the sum of other two angles then prove that triangle is right angled.'
